# %% [markdown]
# # ETL Migration information

# %% [markdown]
# # E - Extraction information

# %% [markdown]
# ### Load libraries

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# #### Load csv

# %%
data_frame_users = pd.read_csv('./user_mock.csv', sep=',')
data_frame_users
# Out:
#               full_name                      email  phone_number  birth_date  \
# 0      Tarrance Snoddon  tsnoddon0@miibeian.gov.cn  353-900-2502   7/10/1986
# 1       Jordon Galliver           jgalliver1@de.vu  330-448-0334   2/10/2008
# 2          Torr Briddle    tbriddle2@woothemes.com  747-696-7381   5/17/2003
# 3           Ivan Bulter        ibulter3@dion.ne.jp  900-677-4739    6/3/1999
# 4    Rickard Burmingham     rburmingham4@google.es  214-183-9461   1/12/1927
# ..                  ...                        ...           ...         ...
# 995     Chrotoem Pardal   cpardalrn@altervista.org  937-152-3002   8/30/1954
# 996    Hester Schuricht  hschurichtro@so-net.ne.jp  427-164-9907   10/1/1933
# 997       Dewey Furlong        dfurlongrp@ebay.com  791-891-2627  10/26/1934
# 998     Lesli de Clercq           lderq@ebay.co.uk  429-977-7958   9/28/1985
# 999          Liana Curd            lcurdrr@home.pl  126-215-8806   8/22/1921
#
#     account_balancer    country
# 0          $40206.95     Brazil
# 1          $63746.71     Mexico
# 2          $35266.07     Sweden
# 3          $17165.85  Indonesia
# 4          $69119.02  Indonesia
# ..               ...        ...
# 995        $56509.47       Peru
# 996        $13774.44     France
# 997        $79436.66    Tunisia
# 998        $21434.88  Indonesia
# 999        $83882.48   Thailand
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Convert data

# %%
data_frame_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   full_name         1000 non-null   object
#  1   email             1000 non-null   object
#  2   phone_number      1000 non-null   object
#  3   birth_date        1000 non-null   object
#  4   account_balancer  1000 non-null   object
#  5   country           1000 non-null   object
# dtypes: object(6)
# memory usage: 47.0+ KB

# %%
data_frame_users['full_name'] = data_frame_users['full_name'].astype(str)
data_frame_users['email'] = data_frame_users['email'].astype(str)
data_frame_users['phone_number'] = data_frame_users['phone_number'].astype(str)
data_frame_users['country'] = data_frame_users['country'].astype(str)
data_frame_users['birth_date'] = pd.to_datetime(data_frame_users['birth_date'],errors='coerce')
data_frame_users['account_balancer'] = (
    data_frame_users['account_balancer']
    .replace('[\$,]', '', regex=True) 
    .astype(float)
)
data_frame_users
# Out:
#               full_name                      email  phone_number birth_date  \
# 0      Tarrance Snoddon  tsnoddon0@miibeian.gov.cn  353-900-2502 1986-07-10
# 1       Jordon Galliver           jgalliver1@de.vu  330-448-0334 2008-02-10
# 2          Torr Briddle    tbriddle2@woothemes.com  747-696-7381 2003-05-17
# 3           Ivan Bulter        ibulter3@dion.ne.jp  900-677-4739 1999-06-03
# 4    Rickard Burmingham     rburmingham4@google.es  214-183-9461 1927-01-12
# ..                  ...                        ...           ...        ...
# 995     Chrotoem Pardal   cpardalrn@altervista.org  937-152-3002 1954-08-30
# 996    Hester Schuricht  hschurichtro@so-net.ne.jp  427-164-9907 1933-10-01
# 997       Dewey Furlong        dfurlongrp@ebay.com  791-891-2627 1934-10-26
# 998     Lesli de Clercq           lderq@ebay.co.uk  429-977-7958 1985-09-28
# 999          Liana Curd            lcurdrr@home.pl  126-215-8806 1921-08-22
#
#      account_balancer    country
# 0            40206.95     Brazil
# 1            63746.71     Mexico
# 2            35266.07     Sweden
# 3            17165.85  Indonesia
# 4            69119.02  Indonesia
# ..                ...        ...
# 995          56509.47       Peru
# 996          13774.44     France
# 997          79436.66    Tunisia
# 998          21434.88  Indonesia
# 999          83882.48   Thailand
#
# [1000 rows x 6 columns]

# %%
data_frame_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   full_name         1000 non-null   object
#  1   email             1000 non-null   object
#  2   phone_number      1000 non-null   object
#  3   birth_date        1000 non-null   datetime64[ns]
#  4   account_balancer  1000 non-null   float64
#  5   country           1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 47.0+ KB

# %% [markdown]
# # Transformation data

# %% [markdown]
# ### clean data ( email and phone_number)
#
#
# - There are not data null in email and phone_number

# %%
data_frame_users_copy = data_frame_users.copy()

# %%
not_null_phone = data_frame_users_copy[['phone_number']].isnull().sum()
not_null_email = data_frame_users_copy[['email']].isnull().sum()

print(f'# Not null in phone_number: {not_null_phone}')
print(f'# Not null in email: {not_null_email}')
# Out:
# # Not null in phone_number: phone_number    0
# dtype: int64
# # Not null in email: email    0
# dtype: int64

# %%
data_frame_users_copy['full_name'] = data_frame_users_copy['full_name'].apply(lambda x: x.title())

# %%
data_frame_users_copy
# Out:
#               full_name                      email  phone_number birth_date  \
# 0      Tarrance Snoddon  tsnoddon0@miibeian.gov.cn  353-900-2502 1986-07-10
# 1       Jordon Galliver           jgalliver1@de.vu  330-448-0334 2008-02-10
# 2          Torr Briddle    tbriddle2@woothemes.com  747-696-7381 2003-05-17
# 3           Ivan Bulter        ibulter3@dion.ne.jp  900-677-4739 1999-06-03
# 4    Rickard Burmingham     rburmingham4@google.es  214-183-9461 1927-01-12
# ..                  ...                        ...           ...        ...
# 995     Chrotoem Pardal   cpardalrn@altervista.org  937-152-3002 1954-08-30
# 996    Hester Schuricht  hschurichtro@so-net.ne.jp  427-164-9907 1933-10-01
# 997       Dewey Furlong        dfurlongrp@ebay.com  791-891-2627 1934-10-26
# 998     Lesli De Clercq           lderq@ebay.co.uk  429-977-7958 1985-09-28
# 999          Liana Curd            lcurdrr@home.pl  126-215-8806 1921-08-22
#
#      account_balancer    country
# 0            40206.95     Brazil
# 1            63746.71     Mexico
# 2            35266.07     Sweden
# 3            17165.85  Indonesia
# 4            69119.02  Indonesia
# ..                ...        ...
# 995          56509.47       Peru
# 996          13774.44     France
# 997          79436.66    Tunisia
# 998          21434.88  Indonesia
# 999          83882.48   Thailand
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Add age

# %%
print(data_frame_users_copy['birth_date'].head())
# Out:
# 0   1986-07-10
# 1   2008-02-10
# 2   2003-05-17
# 3   1999-06-03
# 4   1927-01-12
# Name: birth_date, dtype: datetime64[ns]

# %%
data_frame_users_copy = data_frame_users_copy[data_frame_users_copy['birth_date'] <= pd.Timestamp.now()]
print(data_frame_users_copy['birth_date'])
# Out:
# 0     1986-07-10
# 1     2008-02-10
# 2     2003-05-17
# 3     1999-06-03
# 4     1927-01-12
#          ...
# 995   1954-08-30
# 996   1933-10-01
# 997   1934-10-26
# 998   1985-09-28
# 999   1921-08-22
# Name: birth_date, Length: 1000, dtype: datetime64[ns]

# %%
date_now = pd.Timestamp.now()
data_frame_users_copy['age'] = data_frame_users_copy['birth_date'].apply(
    lambda x: date_now.year - x.year - ((date_now.month, date_now.day) < (x.month, x.day))
)
data_frame_users_copy
# Out:
#               full_name                      email  phone_number birth_date  \
# 0      Tarrance Snoddon  tsnoddon0@miibeian.gov.cn  353-900-2502 1986-07-10
# 1       Jordon Galliver           jgalliver1@de.vu  330-448-0334 2008-02-10
# 2          Torr Briddle    tbriddle2@woothemes.com  747-696-7381 2003-05-17
# 3           Ivan Bulter        ibulter3@dion.ne.jp  900-677-4739 1999-06-03
# 4    Rickard Burmingham     rburmingham4@google.es  214-183-9461 1927-01-12
# ..                  ...                        ...           ...        ...
# 995     Chrotoem Pardal   cpardalrn@altervista.org  937-152-3002 1954-08-30
# 996    Hester Schuricht  hschurichtro@so-net.ne.jp  427-164-9907 1933-10-01
# 997       Dewey Furlong        dfurlongrp@ebay.com  791-891-2627 1934-10-26
# 998     Lesli De Clercq           lderq@ebay.co.uk  429-977-7958 1985-09-28
# 999          Liana Curd            lcurdrr@home.pl  126-215-8806 1921-08-22
#
#      account_balancer    country  age
# 0            40206.95     Brazil   38
# 1            63746.71     Mexico   16
# 2            35266.07     Sweden   21
# 3            17165.85  Indonesia   25
# 4            69119.02  Indonesia   97
# ..                ...        ...  ...
# 995          56509.47       Peru   70
# 996          13774.44     France   91
# 997          79436.66    Tunisia   90
# 998          21434.88  Indonesia   39
# 999          83882.48   Thailand  103
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Add Account_category

# %%
def change_account_category(account_balancer: float) -> str:
    if account_balancer < 10000:
        return 'Low'
    elif 10000 <= account_balancer <= 50000:
        return 'Medium'
    else:
        return 'High'

data_frame_users_copy['account_category'] = data_frame_users_copy['account_balancer'].apply(
    lambda x: change_account_category(float(x))
            
)

data_frame_users_copy
# Out:
#               full_name                      email  phone_number birth_date  \
# 0      Tarrance Snoddon  tsnoddon0@miibeian.gov.cn  353-900-2502 1986-07-10
# 1       Jordon Galliver           jgalliver1@de.vu  330-448-0334 2008-02-10
# 2          Torr Briddle    tbriddle2@woothemes.com  747-696-7381 2003-05-17
# 3           Ivan Bulter        ibulter3@dion.ne.jp  900-677-4739 1999-06-03
# 4    Rickard Burmingham     rburmingham4@google.es  214-183-9461 1927-01-12
# ..                  ...                        ...           ...        ...
# 995     Chrotoem Pardal   cpardalrn@altervista.org  937-152-3002 1954-08-30
# 996    Hester Schuricht  hschurichtro@so-net.ne.jp  427-164-9907 1933-10-01
# 997       Dewey Furlong        dfurlongrp@ebay.com  791-891-2627 1934-10-26
# 998     Lesli De Clercq           lderq@ebay.co.uk  429-977-7958 1985-09-28
# 999          Liana Curd            lcurdrr@home.pl  126-215-8806 1921-08-22
#
#      account_balancer    country  age account_category
# 0            40206.95     Brazil   38           Medium
# 1            63746.71     Mexico   16             High
# 2            35266.07     Sweden   21           Medium
# 3            17165.85  Indonesia   25           Medium
# 4            69119.02  Indonesia   97             High
# ..                ...        ...  ...              ...
# 995          56509.47       Peru   70             High
# 996          13774.44     France   91           Medium
# 997          79436.66    Tunisia   90             High
# 998          21434.88  Indonesia   39           Medium
# 999          83882.48   Thailand  103             High
#
# [1000 rows x 8 columns]

# %%
data_frame_users_copy['id_user'] = data_frame_users_copy.index + 1
data_frame_users_copy
# Out:
#               full_name                      email  phone_number birth_date  \
# 0      Tarrance Snoddon  tsnoddon0@miibeian.gov.cn  353-900-2502 1986-07-10
# 1       Jordon Galliver           jgalliver1@de.vu  330-448-0334 2008-02-10
# 2          Torr Briddle    tbriddle2@woothemes.com  747-696-7381 2003-05-17
# 3           Ivan Bulter        ibulter3@dion.ne.jp  900-677-4739 1999-06-03
# 4    Rickard Burmingham     rburmingham4@google.es  214-183-9461 1927-01-12
# ..                  ...                        ...           ...        ...
# 995     Chrotoem Pardal   cpardalrn@altervista.org  937-152-3002 1954-08-30
# 996    Hester Schuricht  hschurichtro@so-net.ne.jp  427-164-9907 1933-10-01
# 997       Dewey Furlong        dfurlongrp@ebay.com  791-891-2627 1934-10-26
# 998     Lesli De Clercq           lderq@ebay.co.uk  429-977-7958 1985-09-28
# 999          Liana Curd            lcurdrr@home.pl  126-215-8806 1921-08-22
#
#      account_balancer    country  age account_category  id_user
# 0            40206.95     Brazil   38           Medium        1
# 1            63746.71     Mexico   16             High        2
# 2            35266.07     Sweden   21           Medium        3
# 3            17165.85  Indonesia   25           Medium        4
# 4            69119.02  Indonesia   97             High        5
# ..                ...        ...  ...              ...      ...
# 995          56509.47       Peru   70             High      996
# 996          13774.44     France   91           Medium      997
# 997          79436.66    Tunisia   90             High      998
# 998          21434.88  Indonesia   39           Medium      999
# 999          83882.48   Thailand  103             High     1000
#
# [1000 rows x 9 columns]

# %% [markdown]
# # L - Load information in postgres

# %% [markdown]
# #### Conection with potsgres

# %%
engine_postgres = create_engine('postgresql+psycopg2://usersName:password@localhost:5432/databaseName')
connection = engine_postgres.connect()

# %%
data_frame_users_copy.to_sql('customers', engine_postgres, if_exists='append', index=False)
# Out:
# 1000
